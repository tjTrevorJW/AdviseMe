# %%
import pandas as pd
import math

# %%
compSci = pd.read_csv('../../Data/compsciNew.csv')
print compSci
# Out:
#       CRN  **Notes      Course                           Title  SH  \
# 0   15115      NaN  CSC 101-01      Intro to Computer Concepts   3
# 1   15115      NaN         NaN                             NaN NaN
# 2   16542        8  CSC 110-01   Computational Problem Solving   3
# 3   15051        3  CSC 130-01       Intro to Computer Science   3
# 4   15051      NaN         NaN                             NaN NaN
# 5   15053        3  CSC 130-02       Intro to Computer Science   3
# 6   15053      NaN         NaN                             NaN NaN
# 7   15055        3  CSC 130-03       Intro to Computer Science   3
# 8   15055      NaN         NaN                             NaN NaN
# 9   15056        3  CSC 230-01    Elem Data Struc / Algorithms   3
# 10  15057        3  CSC 230-02    Elem Data Struc / Algorithms   3
# 11  15058        3  CSC 230-03    Elem Data Struc / Algorithms   3
# 12  15061        3  CSC 250-01   Foundations of Comp Science I   3
# ...
