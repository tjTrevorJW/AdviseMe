# %%
import pandas as pd
import numpy as np
import math
import os

# %%
fullDF = pd.read_csv('../../Data/Course_Data/tempSmall.csv')
majorDF = pd.read_csv('../../Data/Major_Data/MajorData.csv')

class Student(object):
    name = ""
    classes = []

    def __init__(self, name, classes):
        self.name = name
        self.classes = classes

def make_student(name, classes):
    student = Student(name, classes)
    return student

Jack = make_student('Jack', ['CSC130', 'MAT150', 'MAT293', 'CCI205', 'FRE101', 'CSC529', 'MAT151',])
Jill = make_student('Jill', [])

def recommend(student):
    majorDF.set_value(0, 'Core', majorDF.loc[0].Core.split(","))
    majorDF.set_value(0, 'GFL', majorDF.loc[0].GFL.split(","))
    majorDF.set_value(0, 'MAT', majorDF.loc[0].MAT.split(","))
    fullDF['Prerequisites'].fillna("none", inplace=True)
    for i, row in fullDF.iterrows():
        if "," in row.Prerequisites:
            fullDF.set_value(i, 'Prerequisites', fullDF.loc[i].Prerequisites.split(","))
            
    classList = student.classes
    recDF = fullDF
    majDF = majorDF
    y = "none"
    recDF.to_csv('recommendedData.csv', index=False)
    
    for x in range(len(classList)):
        recDF = recDF[recDF.Course.str.contains(classList[x]) == False]
        if classList[x] in majDF.loc[0].Core:
            majDF.loc[0].Core.remove(classList[x])
        elif classList[x] in majDF.loc[0].MAT:
            del majDF.loc[0].MAT[:]
        elif classList[x] in majDF.loc[0].GFL:
            majDF.loc[0].GFL.remove(classList[x])
        else:
            for i, row in fullDF.iterrows():
                if classList[x] in row.Course:
                    #print(row.Course)
                    if row.Course[0:6] in y:
                        break
                    if ".GLT" in row.Categories:
                        majDF.set_value(0, 'GLT', majDF.loc[0].GLT - 1)
                        if majDF.loc[0].GLT == 0:
                             for i, row in recDF.iterrows():
                                    if ".GLT" in row.Categories:
                                        recDF.set_value(i, 'Score', row.Score - 1)
                    if ".GPR" in row.Categories:
                        majDF.set_value(0, 'GPR', majDF.loc[0].GPR - 1)
                        if majDF.loc[0].GPR == 0:
                             for i, row in recDF.iterrows():
                                    if ".GRP" in row.Categories:
                                        recDF.set_value(i, 'Score', row.Score - 1)
                    if ".GHP" in row.Categories:
                        majDF.set_value(0, 'GHP', majDF.loc[0].GHP - 1)
                        if majDF.loc[0].GHP == 0:
                             for i, row in recDF.iterrows():
                                    if ".GHP" in row.Categories:
                                        recDF.set_value(i, 'Score', row.Score - 1)
                    if ".GRD" in row.Categories:
                        majDF.set_value(0, 'GRD', majDF.loc[0].GRD - 1)
                        if majDF.loc[0].GRD == 0:
                             for i, row in recDF.iterrows():
                                    if ".GRD" in row.Categories:
                                        recDF.set_value(i, 'Score', row.Score - 1)
                    if ".GL" in row.Categories or ".GN" in row.Categories:
                        majDF.set_value(0, 'GLGN', majDF.loc[0].GLGN - 1)
                        if majDF.loc[0].GLGN == 0:
                             for i, row in recDF.iterrows():
                                    if ".GL" in row.Categories or ".GN" in row.Categories:
                                        recDF.set_value(i, 'Score', row.Score - 1)
                    if ".SI" in row.Categories:
                        majDF.set_value(0, 'SI', majDF.loc[0].SI - 1)
                        if majDF.loc[0].SI == 0:
                             for i, row in recDF.iterrows():
                                    if ".SI" in row.Categories:
                                        recDF.set_value(i, 'Score', row.Score - 1)
                    if ".WI" in row.Categories:
                        majDF.set_value(0, 'WI', majDF.loc[0].WI - 1)
                        if majDF.loc[0].WI == 0:
                             for i, row in recDF.iterrows():
                                    if ".WI" in row.Categories:
                                        recDF.set_value(i, 'Score', row.Score - 1)
                    if ".CSC" in row.Categories:
                        majDF.set_value(0, 'CSC', majDF.loc[0].CSC - 1)
                        if majDF.loc[0].CSC == 0:
                             for i, row in recDF.iterrows():
                                    if ".CSC" in row.Categories:
                                        recDF.set_value(i, 'Score', row.Score - 1)
                    y = row.Course
        
    for i, row in recDF.iterrows():
        if row.Prerequisites == "none":
            continue
        if not row.Prerequisites in classList:
            recDF.drop(i, inplace=True)
            
    recDF = recDF[recDF.Score != 0]            
    #recDF.sort_values('Score', inplace=True, ascending=False)
    os.remove('recommendedData.csv')
    recDF.to_csv('recommendedData.csv', index=False)
    return recDF

recDF = recommend(Jill)
print(recDF)
# Out:
#      Unnamed: 0  Unnamed: 0.1    CRN         **Notes       Course  \
# 0             0             0  15115             NaN    CSC101-01
# 39           70            70  15216             NaN    BIO105-01
# 40           71            71  15653       29,30,141   BIO105-01D
# 41           72            72  11379             NaN    BIO105-02
# 42           73            73  11380             NaN    BIO105-03
# 43           74            74  15126       29,30,105   BIO105-81D
# 44           75            75  11381               3   BIO105L-01
# 45           76            76  11382               3   BIO105L-02
# 46           77            77  11383               3   BIO105L-03
# 47           78            78  11384               3   BIO105L-04
# 48           79            79  11385               3   BIO105L-05
# 49           80            80  11386               3   BIO105L-06
# 50           81            81  11387               3   BIO105L-07
# 51           82            82  11388               3   BIO105L-08
# 52           83            83  11389               3   BIO105L-09
# 53           84            84  14189               3   BIO105L-10
# 54           85            85  14190               3   BIO105L-11
# 55           86            86  14191               3   BIO105L-12
# 56           87            87  14193               3   BIO105L-13
# 57           88            88  14194               3   BIO105L-14
# 58           89            89  15222               3   BIO105L-15
# 59           90            90  15322               3   BIO105L-16
# 60           91            91  15225     3,29,30,141  BIO105L-16D
# 61           92            92  15226               3   BIO105L-17
# 62           93            93  15227     3,29,30,141  BIO105L-17D
# 63           94            94  15229               3   BIO105L-18
# 64           95            95  15537     3,29,30,141  BIO105L-18D
# 65           96            96  11390               3    BIO111-01
# 66           97            97  11391               3    BIO111-02
# 67           98            98  11392               3    BIO111-03
# ..          ...           ...    ...             ...          ...
# 418        1142          1142  10528             NaN    PHI220-02
# 419        1143          1143  14315             NaN    PHI222-02
# 420        1144          1144  14314             NaN    PHI222-03
# 421        1145          1145  10533             NaN    PHI252-01
# 422        1146          1146  10534              30    PHI252-02
# 423        1147          1147  12442       26,30,141   PHI252-02D
# 424        1148          1148  13439              30    PHI301-01
# 425        1149          1149  17246       29,30,141   PHI301-01D
# 426        1152          1152  16804             NaN    PHI321-01
# 427        1153          1153  14067             NaN    PHI331-01
# 428        1154          1154  14447       29,30,141   PHI331-01D
# 429        1155          1155  14065              30    PHI359-01
# 430        1156          1156  14468       29,30,141   PHI359-01D
# 431        1157          1157  16963           29,30   PHI361-01D
# 432        1158          1158  16964       29,30,141   PHI361-02D
# 433        1159          1159  12585              30    PHI361-03
# 434        1160          1160  10525              30    PHI361-04
# 435        1161          1161  10526              30    PHI361-05
# 436        1162          1162  14374       29,30,141   PHI361-05D
# 437        1163          1163  13612             NaN    PHI361-06
# 438        1164          1164  16374              30    PHI361-07
# 439        1165          1165  17316       29,30,141   PHI361-07D
# 440        1166          1166  14066              30    PHI361-08
# 441        1167          1167  15804       29,30,141   PHI361-08D
# 442        1168          1168  16376              30    PHI361-09
# 443        1169          1169  17327       29,30,141   PHI361-09D
# 444        1170          1170  12747       29,30,105   PHI361-81D
# 445        1171          1171  16966       29,30,105   PHI361-82D
# 446        1174          1174  10539            3,10    PHI494-01
# 447        1175          1175  14448  3,10,29,30,141   PHI494-01D
#
#                               Title  SH Course Type               Instructor  \
# 0        Intro to Computer Concepts   3         LEC     Jeffrey N. Whitworth
# 39           Major Concepts Biology   3         WEB        Heather Rushforth
# 40           Major Concepts Biology   3         WEB        Heather Rushforth
# 41           Major Concepts Biology   3         LEC            Ann B. Somers
# 42           Major Concepts Biology   3         LEC         Austin N. Craven
# 43           Major Concepts Biology   3         WEB         Malcolm D. Schug
# 44        Major Concepts in Bio Lab   1         LAB        Heather Rushforth
# 45        Major Concepts in Bio Lab   1         LAB        Heather Rushforth
# 46        Major Concepts in Bio Lab   1         LAB        Heather Rushforth
# 47        Major Concepts in Bio Lab   1         LAB        Heather Rushforth
# 48        Major Concepts in Bio Lab   1         LAB        Heather Rushforth
# 49        Major Concepts in Bio Lab   1         LAB        Heather Rushforth
# 50        Major Concepts in Bio Lab   1         LAB        Heather Rushforth
# 51        Major Concepts in Bio Lab   1         LAB        Heather Rushforth
# 52        Major Concepts in Bio Lab   1         LAB        Heather Rushforth
# 53        Major Concepts in Bio Lab   1         LAB        Heather Rushforth
# 54        Major Concepts in Bio Lab   1         LAB             Julia Loreth
# 55        Major Concepts in Bio Lab   1         LAB        Heather Rushforth
# 56        Major Concepts in Bio Lab   1         LAB        Heather Rushforth
# 57        Major Concepts in Bio Lab   1         LAB        Heather Rushforth
# 58        Major Concepts in Bio Lab   1         LAB        Heather Rushforth
# 59        Major Concepts in Bio Lab   1         WEB        Heather Rushforth
# 60        Major Concepts in Bio Lab   1         WEB        Heather Rushforth
# 61        Major Concepts in Bio Lab   1         WEB        Heather Rushforth
# 62        Major Concepts in Bio Lab   1         WEB        Heather Rushforth
# 63        Major Concepts in Bio Lab   1         WEB         Austin N. Craven
# 64        Major Concepts in Bio Lab   1         WEB         Austin N. Craven
# 65          Principles of Biology I   4         LEC     John E. Tomkiel Dean
# 66          Principles of Biology I   4         LEC             Julia Loreth
# 67          Principles of Biology I   4         LEC       Margaret L. Horton
# ..                              ...  ..         ...                      ...
# 418                  Medical Ethics   3         LEC          Heather J. Gert
# 419      Ethics in the Computer Age   3         LEC           Joseph W. Cole
# 420      Ethics in the Computer Age   3         LEC           Joseph W. Cole
# 421       History Modern Philosophy   3         LEC        Adam M. Rosenfeld
# 422       History Modern Philosophy   3         WEB        Adam M. Rosenfeld
# 423       History Modern Philosophy   3         WEB        Adam M. Rosenfeld
# 424      Phil of Art and Aesthetics   3         WEB          Janine C. Jones
# 425  Tpcs:Phil of Art and Aesthetic   3         WEB          Janine C. Jones
# 426                  Ethical Theory   3         LEC        Michael Zimmerman
# 427    Soc and Political Philosophy   3         LEC      Michael B. Matteson
# 428    Soc and Political Philosophy   3         WEB      Michael B. Matteson
# 429          Philosophy of Religion   3         WEB         Gary Rosenkrantz
# 430          Philosophy of Religion   3         WEB         Gary Rosenkrantz
# 431      Ethical Issues in Business   3         WEB             Wade M. Maki
# 432      Ethical Issues in Business   3         WEB             Wade M. Maki
# 433      Ethical Issues in Business   3         WEB      Michael B. Matteson
# 434      Ethical Issues in Business   3         WEB      Michael B. Matteson
# 435      Ethical Issues in Business   3         WEB      Michael B. Matteson
# 436      Ethical Issues in Business   3         WEB      Michael B. Matteson
# 437      Ethical Issues in Business   3         LEC      Michael B. Matteson
# 438      Ethical Issues in Business   3         WEB  Christopher M. Metivier
# 439      Ethical Issues in Business   3         WEB  Christopher M. Metivier
# 440      Ethical Issues in Business   3         WEB           Joseph W. Cole
# 441      Ethical Issues in Business   3         WEB           Joseph W. Cole
# 442      Ethical Issues in Business   3         WEB           Joseph W. Cole
# 443      Ethical Issues in Business   3         WEB           Joseph W. Cole
# 444      Ethical Issues in Business   3         WEB             Wade M. Maki
# 445      Ethical Issues in Business   3         WEB      Michael B. Matteson
# 446   Senior Capstone: Phil of Mind   3         LEC       Frances Bottenberg
# 447          Senior Capstone Course   3         WEB       Frances Bottenberg
#
#                   Meeting Dates  ...        Time  Location        Categories  \
# 0    08-JAN-2018 to 25-APR-2018  ...   1700-1815  PETT 217               .SI
# 39   08-JAN-2018 to 25-APR-2018  ...         NaN       NaN      .GLS.GNS.SUS
# 40   08-JAN-2018 to 25-APR-2018  ...         NaN       NaN      .GLS.GNS.SUS
# 41   08-JAN-2018 to 25-APR-2018  ...   1200-1250  SULV 101      .GLS.GNS.SUS
# 42   08-JAN-2018 to 25-APR-2018  ...   1700-1815  SULV 101      .GLS.GNS.SUS
# 43   09-DEC-2017 to 18-JAN-2018  ...         NaN       NaN      .GLS.GNS.SUS
# 44   08-JAN-2018 to 25-APR-2018  ...   0900-1150  SULV 112      .GLS.GNS.SUS
# 45   08-JAN-2018 to 25-APR-2018  ...   1200-1450  SULV 112      .GLS.GNS.SUS
# 46   08-JAN-2018 to 25-APR-2018  ...   1500-1750  SULV 112      .GLS.GNS.SUS
# 47   08-JAN-2018 to 25-APR-2018  ...   1800-2050  SULV 112      .GLS.GNS.SUS
# 48   08-JAN-2018 to 25-APR-2018  ...   0930-1220  SULV 112      .GLS.GNS.SUS
# 49   08-JAN-2018 to 25-APR-2018  ...   1230-1520  SULV 112      .GLS.GNS.SUS
# 50   08-JAN-2018 to 25-APR-2018  ...   1530-1820  SULV 112      .GLS.GNS.SUS
# 51   08-JAN-2018 to 25-APR-2018  ...   1830-2120  SULV 112      .GLS.GNS.SUS
# 52   08-JAN-2018 to 25-APR-2018  ...   0900-1150  SULV 112      .GLS.GNS.SUS
# 53   08-JAN-2018 to 25-APR-2018  ...   1200-1450  SULV 112      .GLS.GNS.SUS
# 54   08-JAN-2018 to 25-APR-2018  ...   1500-1750  SULV 112      .GLS.GNS.SUS
# 55   08-JAN-2018 to 25-APR-2018  ...   1800-2050  SULV 112      .GLS.GNS.SUS
# 56   08-JAN-2018 to 25-APR-2018  ...   0930-1220  SULV 112      .GLS.GNS.SUS
# 57   08-JAN-2018 to 25-APR-2018  ...   1230-1520  SULV 112      .GLS.GNS.SUS
# 58   08-JAN-2018 to 25-APR-2018  ...   1530-1820  SULV 112      .GLS.GNS.SUS
# 59   08-JAN-2018 to 25-APR-2018  ...         NaN       NaN      .GLS.GNS.SUS
# 60   08-JAN-2018 to 25-APR-2018  ...         NaN       NaN      .GLS.GNS.SUS
# 61   08-JAN-2018 to 25-APR-2018  ...         NaN       NaN      .GLS.GNS.SUS
# 62   08-JAN-2018 to 25-APR-2018  ...         NaN       NaN      .GLS.GNS.SUS
# 63   08-JAN-2018 to 25-APR-2018  ...         NaN       NaN      .GLS.GNS.SUS
# 64   08-JAN-2018 to 25-APR-2018  ...         NaN       NaN      .GLS.GNS.SUS
# 65   08-JAN-2018 to 25-APR-2018  ...   1400-1515  EBER 250  .ENV.GLS.GNS.SUS
# 66   08-JAN-2018 to 25-APR-2018  ...   1000-1050  SOEB 120  .ENV.GLS.GNS.SUS
# 67   08-JAN-2018 to 25-APR-2018  ...   1800-1915  EBER 250  .ENV.GLS.GNS.SUS
# ..                          ...  ...         ...       ...               ...
# 418  08-JAN-2018 to 25-APR-2018  ...   1100-1215  GRAM 204              .GPR
# 419  08-JAN-2018 to 25-APR-2018  ...   0930-1045  SOEB 206              .GPR
# 420  08-JAN-2018 to 25-APR-2018  ...   1100-1215  SOEB 206              .GPR
# 421  08-JAN-2018 to 25-APR-2018  ...   1530-1645  FERG 325       .GHP.GL.GMO
# 422  08-JAN-2018 to 25-APR-2018  ...         NaN       NaN       .GHP.GL.GMO
# 423  08-JAN-2018 to 25-APR-2018  ...         NaN       NaN       .GHP.GL.GMO
# 424  08-JAN-2018 to 25-APR-2018  ...         NaN       NaN               .WI
# 425  08-JAN-2018 to 25-APR-2018  ...         NaN       NaN               .WI
# 426  08-JAN-2018 to 25-APR-2018  ...   0930-1045  NMOR 328               .WI
# 427  08-JAN-2018 to 25-APR-2018  ...   1530-1800  SOEB 224              .GPR
# 428  08-JAN-2018 to 25-APR-2018  ...         NaN       NaN              .GPR
# 429  08-JAN-2018 to 25-APR-2018  ...         NaN       NaN              .GPR
# 430  08-JAN-2018 to 25-APR-2018  ...         NaN       NaN              .GPR
# 431  08-JAN-2018 to 25-APR-2018  ...         NaN       NaN       .GN.GPR.SUS
# 432  08-JAN-2018 to 25-APR-2018  ...         NaN       NaN       .GN.GPR.SUS
# 433  08-JAN-2018 to 25-APR-2018  ...         NaN       NaN       .GN.GPR.SUS
# 434  08-JAN-2018 to 25-APR-2018  ...         NaN       NaN       .GN.GPR.SUS
# 435  08-JAN-2018 to 25-APR-2018  ...         NaN       NaN       .GN.GPR.SUS
# 436  08-JAN-2018 to 25-APR-2018  ...         NaN       NaN       .GN.GPR.SUS
# 437  08-JAN-2018 to 25-APR-2018  ...   1400-1515  SOEB 222       .GN.GPR.SUS
# 438  08-JAN-2018 to 25-APR-2018  ...         NaN       NaN       .GN.GPR.SUS
# 439  08-JAN-2018 to 25-APR-2018  ...         NaN       NaN       .GN.GPR.SUS
# 440  08-JAN-2018 to 25-APR-2018  ...         NaN       NaN   .GN.GPR.IGS.SUS
# 441  08-JAN-2018 to 25-APR-2018  ...         NaN       NaN   .GN.GPR.IGS.SUS
# 442  08-JAN-2018 to 25-APR-2018  ...         NaN       NaN       .GN.GPR.SUS
# 443  08-JAN-2018 to 25-APR-2018  ...         NaN       NaN       .GN.GPR.SUS
# 444  09-DEC-2017 to 18-JAN-2018  ...         NaN       NaN       .GN.GPR.SUS
# 445  09-DEC-2017 to 18-JAN-2018  ...         NaN       NaN       .GN.GPR.SUS
# 446  08-JAN-2018 to 25-APR-2018  ...   1530-1645  CURY 247            .SI.WI
# 447  08-JAN-2018 to 25-APR-2018  ...         NaN       NaN            .SI.WI
#
#     Seats  Limit  Enroll  *Campus           Subject Prerequisites Score
# 0       0     25      25        M  computer science          none     1
# 39      0    115     115        M           biology          none     1
# 40     -8      0       8        D           biology          none     1
# 41     56    295     239        M           biology          none     1
# 42     45    175     130        M           biology          none     1
# 43      5     80      75        D           biology          none     1
# 44      0     24      24        M           biology          none     1
# 45      0     24      24        M           biology          none     1
# 46      0     24      24        M           biology          none     1
# 47      1     24      23        M           biology          none     1
# 48      0     24      24        M           biology          none     1
# 49      1     24      23        M           biology          none     1
# 50      0     24      24        M           biology          none     1
# 51      0     24      24        M           biology          none     1
# 52      0     24      24        M           biology          none     1
# 53      0     24      24        M           biology          none     1
# 54      1     24      23        M           biology          none     1
# 55      0     24      24        M           biology          none     1
# 56      0     24      24        M           biology          none     1
# 57      0     24      24        M           biology          none     1
# 58      2     24      22        M           biology          none     1
# 59      0      9       9        M           biology          none     1
# 60     -1     10      11        D           biology          none     1
# 61      0     10      10        M           biology          none     1
# 62      0     10      10        D           biology          none     1
# 63      0     10      10        M           biology          none     1
# 64      4     10       6        D           biology          none     1
# 65     10    192     182        M           biology          none     3
# 66     13    192     179        M           biology          none     3
# 67     74    180     106        M           biology          none     3
# ..    ...    ...     ...      ...               ...           ...   ...
# 418     4     60      56        M        philosophy          none     1
# 419    -1     40      41        M        philosophy          none     3
# 420     0     40      40        M        philosophy          none     3
# 421     6     50      44        M        philosophy          none     3
# 422     0     33      33        M        philosophy          none     3
# 423   -15      0      15        D        philosophy          none     3
# 424     0     24      24        M        philosophy          none     1
# 425    -2      0       2        D        philosophy          none     1
# 426    13     30      17        M        philosophy          none     1
# 427     8     26      18        M        philosophy          none     1
# 428   -13      0      13        D        philosophy          none     1
# 429     2     36      34        M        philosophy          none     1
# 430    -4      0       4        D        philosophy          none     1
# 431    -2     30      32        D        philosophy          none     2
# 432    -2     30      32        D        philosophy          none     2
# 433     1     59      58        M        philosophy          none     2
# 434     0     59      59        M        philosophy          none     2
# 435     0     57      57        M        philosophy          none     2
# 436    -5      0       5        D        philosophy          none     2
# 437     0     60      60        M        philosophy          none     2
# 438    -1     59      60        M        philosophy          none     2
# 439    -1      0       1        D        philosophy          none     2
# 440     1     56      55        M        philosophy          none     2
# 441    -5      0       5        D        philosophy          none     2
# 442     0     57      57        M        philosophy          none     2
# 443    -3      0       3        D        philosophy          none     2
# 444     0     60      60        D        philosophy          none     2
# 445     3     60      57        D        philosophy          none     2
# 446    10     19       9        M        philosophy          none     2
# 447    -6      0       6        D        philosophy          none     2
#
# [357 rows x 21 columns]
# d:\program files\python36\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# d:\program files\python36\lib\site-packages\ipykernel_launcher.py:21: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# d:\program files\python36\lib\site-packages\ipykernel_launcher.py:22: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# d:\program files\python36\lib\site-packages\ipykernel_launcher.py:26: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
testMaj = majorDF
testRec =fullDF
tempList = Jack.classes

# %%
print(majorDF)
# Out:
#                                                 Core  Senior  GLT  GPR  GHP  \
# 0  [MAT151, CSC130, CSC250, CSC230, CSC350, CSC26...  CSC490    2    1    1
#
#    GRD  GLGN  SI  WI                               GFL  CSC  \
# 0    2     4   1   2  [FRE101, FRE102, FRE203, FRE204]    4
#
#                         MAT
# 0  [MAT293, MAT310, MAT390]
